# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("/workspace/nhi/nli_interference/data/das/granite_pi_relay_r16/L18_row/test_scored.csv")

# %%
df = df.drop(columns=["site", "rank", "condition_on"])

# %%
df
# Out:
#       row_id  run_family                                     sample_id  \
# 0      40800  das_atomic             das_pi_base_0850_idx1_ai+_c+_main
# 1      40801  das_atomic       das_pi_base_0850_idx1_ai+_c+_distractor
# 2      40802  das_atomic             das_pi_base_0850_idx1_ai+_c+_gate
# 3      40803  das_atomic  das_pi_base_0850_idx1_ai+_c+_label_copy_trap
# 4      40804  das_atomic             das_pi_base_0850_idx1_ai+_c-_main
# ...      ...         ...                                           ...
# 7195   47995  das_atomic  das_pi_base_0999_idx3_ai-_c+_label_copy_trap
# 7196   47996  das_atomic             das_pi_base_0999_idx3_ai-_c-_main
# 7197   47997  das_atomic       das_pi_base_0999_idx3_ai-_c-_distractor
# 7198   47998  das_atomic             das_pi_base_0999_idx3_ai-_c-_gate
# 7199   47999  das_atomic  das_pi_base_0999_idx3_ai-_c-_label_copy_trap
#
#      base_event_id  experiment expected_label target_label target_var  \
# ...
